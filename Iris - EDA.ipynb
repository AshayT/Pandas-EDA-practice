# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
setosa = df.loc[df['Species'] == 'Iris-setosa']

# %%
virginica = df.loc[df['Species'] == 'Iris-virginica']

# %%
versicolor = df.loc[df['Species'] == 'Iris-versicolor']

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot(setosa['Sepal.Length'], np.zeros_like(setosa['Sepal.Length']), 'bo')
plt.plot(virginica['Sepal.Length'], np.zeros_like(virginica['Sepal.Length']), 'ro')
plt.plot(versicolor['Sepal.Length'],np.zeros_like(versicolor['Sepal.Length']), 'go')

# %%
sns.FacetGrid(df, hue = 'Species', size = 5).map(plt.scatter,'Petal.Length', 'Sepal.Width').add_legend();

# %%
import seaborn as sns

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df, hue = 'Species')

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64
