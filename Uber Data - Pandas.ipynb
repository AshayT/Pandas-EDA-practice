# %%
import pandas as pd

# %%
df = pd.read_csv('uber_data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df.describe(include = 'all')
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# ...

# %%
df['START*'].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.iloc[0:4,0:5]
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*        STOP*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce  Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce  Fort Pierce

# %%
#loc if want to access with names, pass list to get dataframe

# %%
df.loc[:,['START*']]
# Out:
#                 START*
# 0          Fort Pierce
# 1          Fort Pierce
# 2          Fort Pierce
# 3          Fort Pierce
# 4          Fort Pierce
# ...                ...
# 1151           Kar?chi
# 1152  Unknown Location
# 1153        Katunayake
# 1154           Gampaha
# 1155               NaN
#
# [1156 rows x 1 columns]

# %%
df.loc[0:4, ['START_DATE*', 'MILES*']]
# Out:
#       START_DATE*  MILES*
# 0  1/1/2016 21:11     5.1
# 1   1/2/2016 1:25     5.0
# 2  1/2/2016 20:25     4.8
# 3  1/5/2016 17:31     4.7
# 4  1/6/2016 14:42    63.7

# %%
df.loc[df['MILES*'] >10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
df.loc[df['MILES*'] >10, ['MILES*']]
# Out:
#        MILES*
# 4        63.7
# 9        16.5
# 10       10.8
# 22       15.1
# 23       11.2
# ...       ...
# 1134     11.9
# 1144     12.9
# 1152     16.2
# 1154     48.2
# 1155  12204.7
#
# [316 rows x 1 columns]

# %%
df.loc[df['START*']== 'Cary' ]#if only particular column is needed, just mention it inside
# Out:
#            START_DATE*         END_DATE* CATEGORY* START*        STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business   Cary         Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business   Cary  Morrisville
# 28     1/15/2016 11:43   1/15/2016 12:03  Business   Cary       Durham
# 30     1/18/2016 14:55   1/18/2016 15:06  Business   Cary         Cary
# 34     1/20/2016 10:36   1/20/2016 11:11  Business   Cary      Raleigh
# ...                ...               ...       ...    ...          ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business   Cary         Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business   Cary         Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business   Cary         Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business   Cary  Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business   Cary  Morrisville
#
#       MILES*        PURPOSE*
# 7        0.8         Meeting
# 8        8.3         Meeting
# ...

# %%
df.loc[df['START*'].isin([ 'Cary', 'New York'])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
df1 = df.loc[df['START*'].isin(['Cary', 'Morrisville']) & (df['MILES*']>10)]
df1
# Out:
#            START_DATE*         END_DATE* CATEGORY* START*          STOP*  \
# 28     1/15/2016 11:43   1/15/2016 12:03  Business   Cary         Durham
# 34     1/20/2016 10:36   1/20/2016 11:11  Business   Cary        Raleigh
# 46     1/27/2016 10:19   1/27/2016 10:48  Business   Cary        Raleigh
# 50     1/28/2016 12:28   1/28/2016 13:00  Business   Cary        Raleigh
# 55     1/29/2016 11:43   1/29/2016 12:03  Business   Cary         Durham
# ...                ...               ...       ...    ...            ...
# 990   11/22/2016 15:51  11/22/2016 16:43  Business   Cary           Cary
# 997   11/25/2016 11:47  11/25/2016 12:04  Business   Cary         Durham
# 1035   12/9/2016 22:03   12/9/2016 22:57  Business   Cary           Cary
# 1036  12/10/2016 12:43  12/10/2016 13:16  Business   Cary  Fuquay-Varina
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business   Cary    Morrisville
#
#       MILES*        PURPOSE*
# 28      10.4  Meal/Entertain
# 34      17.1         Meeting
# ...

# %%
df2 = df1.reset_index()

# %%
df2.head()
# Out:
#    index      START_DATE*        END_DATE* CATEGORY* START*    STOP*  MILES*  \
# 0     28  1/15/2016 11:43  1/15/2016 12:03  Business   Cary   Durham    10.4
# 1     34  1/20/2016 10:36  1/20/2016 11:11  Business   Cary  Raleigh    17.1
# 2     46  1/27/2016 10:19  1/27/2016 10:48  Business   Cary  Raleigh    18.7
# 3     50  1/28/2016 12:28  1/28/2016 13:00  Business   Cary  Raleigh    19.0
# 4     55  1/29/2016 11:43  1/29/2016 12:03  Business   Cary   Durham    10.4
#
#          PURPOSE*
# 0  Meal/Entertain
# 1         Meeting
# 2  Customer Visit
# 3  Temporary Site
# 4         Meeting

# %%
df1.head()
# Out:
#         START_DATE*        END_DATE* CATEGORY* START*    STOP*  MILES*  \
# 28  1/15/2016 11:43  1/15/2016 12:03  Business   Cary   Durham    10.4
# 34  1/20/2016 10:36  1/20/2016 11:11  Business   Cary  Raleigh    17.1
# 46  1/27/2016 10:19  1/27/2016 10:48  Business   Cary  Raleigh    18.7
# 50  1/28/2016 12:28  1/28/2016 13:00  Business   Cary  Raleigh    19.0
# 55  1/29/2016 11:43  1/29/2016 12:03  Business   Cary   Durham    10.4
#
#           PURPOSE*
# 28  Meal/Entertain
# 34         Meeting
# 46  Customer Visit
# 50  Temporary Site
# 55         Meeting

# %%
df1.reset_index(inplace = True, drop = True)

# %%
df1.head()
# Out:
#        START_DATE*        END_DATE* CATEGORY* START*    STOP*  MILES*  \
# 0  1/15/2016 11:43  1/15/2016 12:03  Business   Cary   Durham    10.4
# 1  1/20/2016 10:36  1/20/2016 11:11  Business   Cary  Raleigh    17.1
# 2  1/27/2016 10:19  1/27/2016 10:48  Business   Cary  Raleigh    18.7
# 3  1/28/2016 12:28  1/28/2016 13:00  Business   Cary  Raleigh    19.0
# 4  1/29/2016 11:43  1/29/2016 12:03  Business   Cary   Durham    10.4
#
#          PURPOSE*
# 0  Meal/Entertain
# 1         Meeting
# 2  Customer Visit
# 3  Temporary Site
# 4         Meeting

# %%
df.sort_values(by = ['MILES*'], ascending = False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
df.sort_values(by = ['START*', 'MILES*'], ascending = [True, False])
# Out:
#            START_DATE*         END_DATE* CATEGORY*         START*  \
# 906    11/4/2016 21:04   11/4/2016 21:20  Business          Agnew
# 911    11/6/2016 10:50   11/6/2016 11:04  Business          Agnew
# 908     11/5/2016 8:34    11/5/2016 8:43  Business          Agnew
# 910    11/5/2016 19:20   11/5/2016 19:28  Business          Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business         Almond
# ...                ...               ...       ...            ...
# 889    11/1/2016 17:35   11/1/2016 17:42  Business    Whitebridge
# 890    11/1/2016 19:14   11/1/2016 19:20  Business    Whitebridge
# 516     7/5/2016 16:48    7/5/2016 16:52  Business    Whitebridge
# 870   10/28/2016 18:13  10/28/2016 20:07  Business  Winston Salem
# 1155            Totals               NaN       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*
# 906          Cory      4.3              NaN
# 911   Renaissance      2.4              NaN
# ...

# %%
import numpy as np

# %%
df['Trip length'] = np.where(df['MILES*']>10, 'long', 'medium')

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* Trip length
# 0          Fort Pierce      5.1   Meal/Entertain      medium
# ...

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* Trip length
# 0          Fort Pierce      5.1   Meal/Entertain      medium
# ...

# %%
df  = df.drop('Trip length', axis = 1)

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#making group by start location and then calculating average distance travelled

# %%
df.groupby('START*')['MILES*'].agg('mean')
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64

# %%
df.groupby('START*')['MILES*'].mean()
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64

# %%
df.groupby('START*').mean() #when only onw column is int format
# Out:
#                      MILES*
# START*
# Agnew              2.775000
# Almond            15.200000
# Apex               5.341176
# Arabi             17.000000
# Arlington          4.900000
# ...                     ...
# West University    2.200000
# Weston             4.000000
# Westpark Place     2.182353
# Whitebridge        4.020588
# Winston Salem    133.600000
#
# [177 rows x 1 columns]

# %%
df.groupby(['START*', 'STOP*']).agg(['mean', 'sum']).head(20)
# Out:
#                                                          MILES*
#                                                            mean    sum
# START*                    STOP*
# Agnew                     Agnew                        2.200000    2.2
#                           Cory                         4.300000    4.3
#                           Renaissance                  2.300000    4.6
# Almond                    Bryson City                 15.200000   15.2
# Apex                      Apex                         2.150000    4.3
#                           Cary                         5.792308   75.3
#                           Eagle Rock                   2.200000    2.2
#                           Holly Springs                9.000000    9.0
# Arabi                     Metairie                    17.000000   17.0
# Arlington                 Washington                   4.900000    4.9
# Arlington Park at Amberly Lexington Park at Amberly    1.300000    1.3
# ...

# %%
df.groupby(['START*']).agg(['mean', 'sum'])
# Out:
#                      MILES*
#                        mean    sum
# START*
# Agnew              2.775000   11.1
# Almond            15.200000   15.2
# Apex               5.341176   90.8
# Arabi             17.000000   17.0
# Arlington          4.900000    4.9
# ...                     ...    ...
# West University    2.200000    4.4
# Weston             4.000000    8.0
# Westpark Place     2.182353   37.1
# Whitebridge        4.020588  273.4
# Winston Salem    133.600000  133.6
#
# [177 rows x 2 columns]

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Jupyter\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-173-12948f550e96> in <module>
# ----> 1 df['START_DATE*'] = pd.to_datetime(df['START_DATE*'])
#
# ...

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df = df.iloc[:-1, :]
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Kar?chi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'])

# %%
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
hello = df.groupby(['START*']).agg({'MILES*':'mean', 'START_DATE*':['min', 'max']})

# %%
hello
# Out:
#                      MILES*       START_DATE*
#                        mean               min               max
# START*
# Agnew              2.775000   11/4/2016 21:04   11/6/2016 10:50
# Almond            15.200000  10/30/2016 12:58  10/30/2016 12:58
# Apex               5.341176   1/29/2016 21:21   8/10/2016 19:47
# Arabi             17.000000   6/25/2016 10:50   6/25/2016 10:50
# Arlington          4.900000    8/2/2016 11:51    8/2/2016 11:51
# ...                     ...               ...               ...
# West University    2.200000   3/10/2016 14:39   3/16/2016 18:43
# Weston             4.000000    3/5/2016 12:57    6/5/2016 15:57
# Westpark Place     2.182353   11/2/2016 15:45   8/12/2016 18:56
# Whitebridge        4.020588    1/19/2016 9:09    8/9/2016 14:20
# Winston Salem    133.600000  10/28/2016 18:13  10/28/2016 18:13
#
# [177 rows x 3 columns]

# %%
hello.reset_index(inplace = True)

# %%
hello
# Out:
#               START*      MILES*       START_DATE*
#                             mean               min               max
# 0              Agnew    2.775000   11/4/2016 21:04   11/6/2016 10:50
# 1             Almond   15.200000  10/30/2016 12:58  10/30/2016 12:58
# 2               Apex    5.341176   1/29/2016 21:21   8/10/2016 19:47
# 3              Arabi   17.000000   6/25/2016 10:50   6/25/2016 10:50
# 4          Arlington    4.900000    8/2/2016 11:51    8/2/2016 11:51
# ..               ...         ...               ...               ...
# 172  West University    2.200000   3/10/2016 14:39   3/16/2016 18:43
# 173           Weston    4.000000    3/5/2016 12:57    6/5/2016 15:57
# 174   Westpark Place    2.182353   11/2/2016 15:45   8/12/2016 18:56
# 175      Whitebridge    4.020588    1/19/2016 9:09    8/9/2016 14:20
# 176    Winston Salem  133.600000  10/28/2016 18:13  10/28/2016 18:13
#
# [177 rows x 4 columns]

# %%
hello.columns = ['Start location', 'avg_distance', 'first_ride_date', 'recent_ride_date']

# %%
hello
# Out:
#       Start location  avg_distance   first_ride_date  recent_ride_date
# 0              Agnew      2.775000   11/4/2016 21:04   11/6/2016 10:50
# 1             Almond     15.200000  10/30/2016 12:58  10/30/2016 12:58
# 2               Apex      5.341176   1/29/2016 21:21   8/10/2016 19:47
# 3              Arabi     17.000000   6/25/2016 10:50   6/25/2016 10:50
# 4          Arlington      4.900000    8/2/2016 11:51    8/2/2016 11:51
# ..               ...           ...               ...               ...
# 172  West University      2.200000   3/10/2016 14:39   3/16/2016 18:43
# 173           Weston      4.000000    3/5/2016 12:57    6/5/2016 15:57
# 174   Westpark Place      2.182353   11/2/2016 15:45   8/12/2016 18:56
# 175      Whitebridge      4.020588    1/19/2016 9:09    8/9/2016 14:20
# 176    Winston Salem    133.600000  10/28/2016 18:13  10/28/2016 18:13
#
# [177 rows x 4 columns]

# %%
hello.to_csv('hello.csv')

# %%
hello.to_csv('hello1.csv', index = False) #if don't want index in csv file
